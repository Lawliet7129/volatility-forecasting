# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf
import duckdb

# %%
df = pd.read_csv("../data/bronze/prices_all.csv", parse_dates = ["date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1318277 entries, 0 to 1318276
# Data columns (total 8 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   date       1318277 non-null  datetime64[ns]
#  1   open       1318277 non-null  float64
#  2   high       1318277 non-null  float64
#  3   low        1318277 non-null  float64
#  4   close      1318277 non-null  float64
#  5   adj_close  1318277 non-null  float64
#  6   volume     1318277 non-null  float64
#  7   ticker     1318277 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 80.5+ MB

# %%
# Check the column names and data types
print("Column names:", df.columns.tolist())
print("\nData types:")
print(df.dtypes)
print("\nFirst few rows:")
print(df.head())
# Out:
# Column names: ['open', 'high', 'low', 'close', 'adj_close', 'volume', 'ticker']
#
# Data types:
# open         float64
# high         float64
# low          float64
# close        float64
# adj_close    float64
# volume       float64
# ticker        object
# dtype: object
#
# First few rows:
#                  open       high        low      close  adj_close     volume  \
# date
# 2015-01-02  41.180000  41.310001  40.369999  40.560001  37.120953  1529200.0
# 2015-01-02  40.270000  40.750000  40.189999  40.570000  33.443081  2346600.0
# 2015-01-02  13.860000  13.870000  13.510000  13.700000   9.239816  5228700.0
# 2015-01-02  90.610001  91.320000  89.820000  90.459999  66.464012  1124600.0
# 2015-01-02  47.419998  47.660000  46.564999  46.865002  42.178173  1815200.0
#
#            ticker
# date
# 2015-01-02      A
# 2015-01-02    RSG
# 2015-01-02    AES
# 2015-01-02    COR
# 2015-01-02   ROST

# %%
df.set_index("date", inplace=True)
# Out:
# Index name: date
# Index type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
df = df.sort_values("date")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/r2/hnc667yd6t55w97_4cgxqqyc0000gp/T/ipykernel_31072/3462287292.py in ?()
# ----> 1 df.set_index("date", inplace=True)
#
# ~/anaconda3/envs/vol/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['date'] are in the columns"
